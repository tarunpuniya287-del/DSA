# %%
import pandas as pd
data = {
    "Student_Id" : range(1,11),
    "Gender": ['Male','Female','Female','Male','Female','Male','Male','Female','Male','Female'],
    'Math' : [78,85,62,90,88,76,69,95,80,84],
    'Science' : [72,88,65,92,90,70,68,94,75,86],
    'English' : [75,82,70,88,91,74,72,90,78,85],
    'Study_Hours' : [4,6,3,7,8,4,3,9,5,6]
}
df = pd.DataFrame(data)
df.head()
# Out:
#    Student_Id  Gender  Math  Science  English  Study_Hours
# 0           1    Male    78       72       75            4
# 1           2  Female    85       88       82            6
# 2           3  Female    62       65       70            3
# 3           4    Male    90       92       88            7
# 4           5  Female    88       90       91            8
